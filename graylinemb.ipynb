# %%
#pip install pandas openpyxl
import sys
# !{sys.executable} -m pip install openpyxl
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
import os
print(os.listdir('data'))
# Out:
# ['2018 Accident Incident Report.xlsx', '2019 Accident Report.xlsx', '2020 Accident Report.xlsx', '2021 Accident Report.xlsx', 'accidents_2024.csv', 'accidents_2025.csv', 'accidents_2025_preventable_addition.csv', 'grayline_fleet_vehicles.csv']

# %%
accidents2018_df = pd.read_excel('data/2018 Accident Incident Report.xlsx', sheet_name = 'Sheet1',skiprows=2, engine='openpyxl')
accidents2019_df = pd.read_excel('data/2019 Accident Report.xlsx',sheet_name = 'DRIVER FAULT',skiprows=1, engine='openpyxl')
accidents2020_df = pd.read_excel('data/2020 Accident Report.xlsx', sheet_name = 'Master', engine='openpyxl')
accidents2021_df = pd.read_excel('data/2021 Accident Report.xlsx', sheet_name = 'Master', engine='openpyxl')
accidents2024_df = pd.read_csv('data/accidents_2024.csv')
accidents2025_df = pd.read_csv('data/accidents_2025.csv')
accidents2025prevent_df = pd.read_csv('data/accidents_2025_preventable_addition.csv')
graylinefleet_df = pd.read_csv('data/grayline_fleet_vehicles.csv')

# %%
accidents2018_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 22 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Claim #                                          128 non-null    object
#  1   Employee Name                                    128 non-null    object
#  2   Dept.                                            116 non-null    object
#  3   Date Occurred                                    127 non-null    object
#  4   Incident / Accident                              126 non-null    object
#  5   DOT Recordable?                                  126 non-null    object
#  6   Unit No.                                         120 non-null    object
#  7   Description                                      123 non-null    object
#  8   GL Driver                                        69 non-null     object
# ...

# %%
acc2018renamed_df = accidents2018_df.rename(columns = {'Claim #':'ClaimNo', 'Employee Name':'DriverName', 'Dept.':'Department', 'Date Occurred ':'AccidentDate',\
                                                      'Incident / Accident':'IncidentAccident', 'DOT Recordable?' : 'DotRecordable', 'Unit No.':'UnitNo', 'GL Driver':'GLDriver', \
                                                      'NON GL Driver ':'NonGLdriver', 'GL Employee':'GLEmployee', 'NON GL Employee':'NonGLEmployee',  \
                                                      'Ins. Notified':'InsNotified', 'In-House, Protective, or Other Driver/Insuance ':'ClaimType', "Jerry's $ GL Bus Repair ":'JerrysBusRepair', \
                                                      'Actual':'Actual', 'Cost for other vehicle repair':'CostForOtherVehicleRepair', 'Police Report':'PoliceReport', \
                                                      'Drive Cam?':'DriveCam', 'Safety Committee Ruling':'SafetyCommRuling','DOT Recordable?':'Dot Recordable', \
                                                      'Status':'ClaimStatus'})

# %%
accidents2018_df['Year']=2018

# %%
accidents2018_df.columns
# Out:
# Index(['Claim #', 'Employee Name', 'Dept.', 'Date Occurred ',
#        'Incident / Accident', 'DOT Recordable?', 'Unit No.', 'Description',
#        'GL Driver', 'NON GL Driver ', 'GL Employee', 'NON GL Employee',
#        'Ins. Notified', 'In-House, Protective, or Other Driver/Insuance ',
#        'Jerry's $ GL Bus Repair ', 'Quote', 'Cost for other vehicle repair',
#        'Actual', 'Police Report', 'Drive Cam?', 'Safety Committee Ruling',
#        'Status', 'Year'],
#       dtype='object')

# %%
acc2018renamed_df['Year']=2018

# %%
acc2018renamed_df.head()
# Out:
#        ClaimNo          DriverName  Department         AccidentDate  \
# 0   010318-533  Brittney Patterson  School Bus  2018-01-04 00:00:00
# 1  010718-1015       Scott Wangrud     Charter  2018-01-07 00:00:00
# 2  011518-1021        Thomas House     Charter  2018-01-15 00:00:00
# 3  011618-1015     David Armstrong     Charter  2018-01-16 00:00:00
# 4   011918-232    William Moncrief        Tour  2018-01-19 00:00:00
#
#   IncidentAccident Dot Recordable UnitNo  \
# 0         Incident        Non-DOT    533
# 1         Incident        Non-DOT   1015
# 2        Accident         Non-DOT   1021
# 3        Accident         Non-DOT   1015
# 4        Accident         Non-DOT    232
#
#                                          Description GLDriver NonGLdriver  \
# 0              Driver hit a sign, no damage reported        X         NaN
# 1              Supposedly hit an Anchor Bus' mirror         X         NaN
# 2                                 Driver hit a sign         X         NaN
# ...

# %%
accidents2019_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Claim #                  158 non-null    object
#  1   Other Claim #            27 non-null     object
#  2   Driver                   158 non-null    object
#  3   Dept.                    154 non-null    object
#  4   Unit #                   154 non-null    object
#  5   Date                     154 non-null    datetime64[ns]
#  6   Description              154 non-null    object
#  7   GL Driver                154 non-null    object
#  8   NON GL Driver            154 non-null    object
#  9   GL Employee              154 non-null    object
#  10  NON GL Employee          154 non-null    object
#  11  Ins Notified?            154 non-null    object
#  12  In-House/Ins             154 non-null    object
#  13  GL Repair Cost           145 non-null    object
# ...

# %%
accidents2019_df.columns
# Out:
# Index(['Claim #', 'Other Claim #', 'Driver', 'Dept.', 'Unit #', 'Date',
#        'Description', 'GL Driver', 'NON GL Driver ', 'GL Employee',
#        'NON GL Employee', 'Ins Notified?', 'In-House/Ins ', 'GL Repair Cost ',
#        '3rd Party Cost', 'Ins Fees', 'Time', 'Location', 'Weather', 'Lighting',
#        'Road Surface', 'Road Type', 'Control Device', 'Driver Experience',
#        'Raduis', 'Police Report', 'DOT Recordable?', 'Drive Cam?',
#        'Safety Committee Ruling', 'Status'],
#       dtype='object')

# %%
accidents2019_df['Year']=2019

# %%
acc2019renamed_df = accidents2019_df.rename(columns = {'Claim #':'ClaimNo', 'Other Claim #':'InsClaimNo', 'Driver':'DriverName', \
                                                      'Dept.':'Department', 'Unit #':'UnitNo', 'Date':'AccidentDate',  \
                                                      'GL Driver':'GLDriver', 'NON GL Driver ':'NonGLDriver', 'GL Employee': 'GLEmployee',\
                                                       'NON GL Employee':'NonGLEmployee', 'Ins Notified?':'InsNotified', \
                                                      'In-House/Ins ':'ClaimType', 'GL Repair Cost ':'GLRepairCost', '3rd Party Cost':'3rdPartyCost',\
                                                      'Ins Fees':'Insfee', \
                                                      'Road Surface':'RoadSurface', 'Road Type':'RoadType', 'Control Device':'ControlDevice', \
                                                      'Driver Experience':'DriverExperience', 'Police Report':'PoliceReport', \
                                                      'DOT Recordable?':'DotRecordable', 'Drive Cam?':'DriveCam', 'Safety Committee Ruling':'SafetyCommRuling', \
                                                      'Status':'ClaimStatus',})

# %%
acc2019renamed_df['Year']=2019

# %%
acc2019renamed_df.head()
# Out:
#        ClaimNo InsClaimNo      DriverName Department UnitNo AccidentDate  \
# 0   010719-003        NaN  Jerry Mischler       Shop      7   2019-01-07
# 1   011719-616        NaN    Rawand Koyee         SB    616   2019-01-17
# 2  011719-1021        NaN    Shawn Yokley          C   1021   2019-01-17
# 3   012019-727        NaN   James Johnson         BC   4727   2019-01-20
# 4  012719-1023        NaN    Sadie Demoss         SS   1023   2019-01-27
#
#                                          Description GLDriver NonGLDriver  \
# 0  GL Mechanic hit another vehicle in an intersec...        Y           N
# 1             Backed into 565 front passenger window        Y           N
# 2                hooked back bumper on a cement pole        Y           N
# 3                   Hit pole in garage on right side        Y           N
# 4                 driver backed 1023 into 243 mirror        Y           N
#
#   GLEmployee  ...  RoadType  ControlDevice DriverExperience Raduis  \
# ...

# %%
accidents2020_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 33 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CLAIM NUMBER          50 non-null     object
#  1   CLAIM NUMBER2         50 non-null     int64
#  2   DRIVER NAME           50 non-null     object
#  3   EMPLOYEE ID           50 non-null     int64
#  4   DEPARTMENT            50 non-null     object
#  5   UNIT NO               50 non-null     int64
#  6   ACC DATE              50 non-null     datetime64[ns]
#  7   DESCRIPTION           50 non-null     object
#  8   DRIVER INJURED        50 non-null     bool
#  9   OP INJURED            50 non-null     bool
#  10  CLAIM TYPE            49 non-null     object
#  11  GL BUS ESTIMATE       50 non-null     float64
#  12  GL BUS REPAIR         50 non-null     float64
#  13  GL FINAL COST         50 non-null     float64
#  14  OP REPAIR COST        50 non-null     float64
# ...

# %%
accidents2020_df.columns
# Out:
# Index(['CLAIM NUMBER', 'CLAIM NUMBER2', 'DRIVER NAME', 'EMPLOYEE ID',
#        'DEPARTMENT', 'UNIT NO', 'ACC DATE', 'DESCRIPTION', 'DRIVER INJURED',
#        'OP INJURED', 'CLAIM TYPE', 'GL BUS ESTIMATE', 'GL BUS REPAIR',
#        'GL FINAL COST', 'OP REPAIR COST', 'INS FEE', 'OP INS PAID TO GL',
#        'INSURANCE DEDUCTIBLE', 'TOTAL', 'TIME', 'LOCATION', 'WEATHER',
#        'LIGHTING', 'ROAD SURFACE', 'ROAD TYPE', 'DRIVER ACTION',
#        'DRIVER EXPERIENCE', 'RADIUS', 'POLICE REPORT', 'DOT RECORDABLE',
#        'VIDEO', 'PREVENTABLE?', 'STATUS'],
#       dtype='object')

# %%
acc2020renamed_df = accidents2020_df.rename(columns = {'CLAIM NUMBER' : 'ClaimNo', 'CLAIM NUMBER2' : 'InsClaimNo', 'DRIVER NAME' : 'DriverName',\
                                                      'EMPLOYEE ID' : 'EmployeeId',  'DEPARTMENT' : 'Department', 'ACC DATE': 'AccidentDate', \
                                                      'DESCRIPTION' : 'Description', 'DRIVER INJURED' : 'DriverInjured', 'OP INJURED' : 'OpInjured', \
                                                      'CLAIM TYPE' : 'ClaimType', 'GL BUS ESTIMATE' : 'GLBusEstimate', 'GL BUS REPAIR' : 'GLBusRepair', \
                                                      'OP REPAIR COST' : 'OpRepairCost', 'INS FEE' : 'InsFee', 'OP INS PAID TO GL' : 'OpInsPaid', \
                                                      'INSURANCE DEDUCTIBLE' : 'InsDeductable', 'TOTAL' : 'Total', 'TIME' : 'Time', 'LOCATION' : 'Location', \
                                                      'WEATHER' : 'Weather', 'LIGHTING' : 'Lighting', 'ROAD SURFACE' : 'RoadSurface', 'ROAD TYPE' : 'RoadType', \
                                                      'DRIVER ACTION' : 'DriverAction','DRIVER EXPERIENCE' : 'DriverExperience', 'RADIUS' : 'Radius', 'POLICE REPORT' : 'PoliceReport', \
                                                      'DOT RECORDABLE' : 'DotRecordable', 'VIDEO' : 'Video', 'PREVENTABLE?' : 'Preventable', \
                                                      'STATUS' : 'ClaimStatus', 'UNIT NO' : 'UnitNo'})

# %%
acc2020renamed_df['Year']=2020

# %%
acc2020renamed_df.head()
# Out:
#        ClaimNo  InsClaimNo        DriverName  EmployeeId   Department  UnitNo  \
# 0   010620-246           0     Alesha Harney       11038      Charter     246
# 1   010820-214           0  Kelly Westerlund       10979  Sightseeing     214
# 2  010920-1019      767903   Robert Kimbrell       10346      Charter    1019
# 3  010920-1019           0   Robert Kimbrell       10346      Charter    1019
# 4   011020-721      767935   Michael Beattie       10039          RTA     721
#
#   AccidentDate                                        Description  \
# 0   2020-01-06  car hit the front bumper of the bus - scuffed ...
# 1   2020-01-08  driver hit a service truck turning right, bus ...
# 2   2020-01-09  driver clipped a college student when she drov...
# 3   2020-01-09  driver failed to set brake and bus rolled into...
# 4   2020-01-10  hit OP right rear fender turning left at Charl...
#
#    DriverInjured  OpInjured  ...            RoadType   DriverAction  \
# ...

# %%
accidents2021_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 31 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ClaimNo          92 non-null     object
#  1   InsClaimNo       91 non-null     float64
#  2   DRIVERNAME       97 non-null     object
#  3   EmployeeID       18 non-null     float64
#  4   DEPT             96 non-null     object
#  5   UnitNo           96 non-null     object
#  6   AccidentDate     97 non-null     datetime64[ns]
#  7   DESCRIPTION      97 non-null     object
#  8   OPFAULT          87 non-null     float64
#  9   INJURY           93 non-null     object
#  10  ClaimType        37 non-null     object
#  11  GLEstimate       18 non-null     float64
#  12  Final            18 non-null     float64
#  13  OPRepair         19 non-null     float64
#  14  Total            97 non-null     float64
#  15  TIME             95 non-null     object
# ...

# %%
accidents2021_df.columns
# Out:
# Index(['ClaimNo', 'InsClaimNo', 'DRIVERNAME', 'EmployeeID', 'DEPT', 'UnitNo',
#        'AccidentDate', 'DESCRIPTION', 'OPFAULT', 'INJURY', 'ClaimType',
#        'GLEstimate', 'Final', 'OPRepair', 'Total', 'TIME', 'LOCATION',
#        'CityState', 'WEATHER', 'LIGHTING', 'RoadSurface', 'RoadType',
#        'DriverAction', 'PoliceReport', 'DOTRecordable', 'VIDEO', 'PREV',
#        'STATUS', 'ClaimAdj', 'NOTES', 'VMS Accident No'],
#       dtype='object')

# %%
acc2021renamed_df = accidents2021_df.rename(columns = {'DRIVERNAME' : 'DriverName',\
                                                      'DEPT' : 'Department', 'DESCRIPTION' : 'Description', \
                                                      'OPFAULT' : 'OpFault', 'INJURY' : 'Injury', 'GL Estimate':'GLBusEstimate', 'OPRepair':'OpRepair',\
                                                      'TIME':'Time', 'LOCATION':'Location', 'WEATHER':'Weather', \
                                                      'LIGHTING':'Lighting', \
                                                      'DOTRecordable' : 'DotRecordable', 'VIDEO': 'Video', 'PREV':'Preventable', \
                                                      'Date Occured': 'AccidentDate',  'ClaimType' : 'ClaimType','STATUS' : 'ClaimStatus',\
                                                      'NOTES':'Notes', 'VMS Accident No':'VmsAccidentNo'})

# %%
acc2021renamed_df['Year']=2021

# %%
acc2021renamed_df.head(5)
# Out:
#        ClaimNo  InsClaimNo          DriverName  EmployeeID  Department UnitNo  \
# 0   011321-715       110.0    Elizabeth Burton     10086.0         RTA    715
# 1   011421-280       111.0    Robert Schneider     11016.0         RTA    280
# 2   011721-329       112.0       Anthony Wells     10914.0     Charter    329
# 3  011721-4101    768974.0        Sameh Shaker     10566.0  School Bus   4101
# 4   011921-000    235957.0  Jenniefer Stephens     10597.0     Charter      0
#
#   AccidentDate                                        Description  OpFault  \
# 0   2021-01-13  Penske truck hit passenger side mirror of bus ...      1.0
# 1   2021-01-14  a bobcat truck pulling a 36' to 40' constructi...      1.0
# 2   2021-01-17  driver backed into a pay booth,  rear screen o...      0.0
# 3   2021-01-17  Our bus was parked on the side of the road whe...      1.0
# 4   2021-01-19  IW was closing tire cover when the bumper clos...      0.0
#
# ...

# %%
accidents2024_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190 entries, 0 to 189
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   claimno                  190 non-null    object
#  1   insclaimno               190 non-null    object
#  2   drivername               190 non-null    object
#  3   employeeid               190 non-null    object
#  4   dept                     190 non-null    object
#  5   unitno                   190 non-null    object
#  6   accidentdate             190 non-null    object
#  7   description              190 non-null    object
#  8   preventable?             190 non-null    object
#  9   injury                   190 non-null    object
#  10  loss_of_bonus_           190 non-null    object
#  11  coaching                 190 non-null    object
#  12  final___jerrys_estimate  190 non-null    object
#  13  est                      190 non-null    object
# ...

# %%
accidents2024_df.columns
# Out:
# Index(['claimno', 'insclaimno', 'drivername', 'employeeid', 'dept', 'unitno',
#        'accidentdate', 'description', 'preventable?', 'injury',
#        'loss_of_bonus_', 'coaching', 'final___jerrys_estimate', 'est',
#        'oprepair', 'total', 'time', 'address', 'citystate', 'weather',
#        'lighting', 'roadsurface', 'roadtype', 'driveraction', 'policereport',
#        'dotrecordable', 'video', 'prev', 'status', 'claimadj', 'notes',
#        'vms_accident_no'],
#       dtype='object')

# %%
acc2024renamed_df = accidents2024_df.rename(columns = {'claimno':'ClaimNo', 'insclaimno':'InsClaimNo', 'drivername':'DriverName','employeeid':'EmployeeID', \
                                                       'dept' : 'Department', 'unitno' : 'UnitNo', 'accidentdate':'AccidentDate', 'description':'Description','preventable?':'Preventable', \
                                                      'injury':'Injury','loss_of_bonus_':'LossOfBonus', 'final___jerrys_estimate':'FinalJerrysEstimate','est':'Estimate','oprepair':'OpRepair', \
                                                      'total':'Total','time':'Time', 'address':'Address', 'citystate':'CityState', 'weather':'Weather',\
                                                       'lightning':'Lightning', 'roadsurface':'RoadSurface', 'roadtype':'RoadType', 'driveraction':'DriverAction', 'policereport':'PoliceReport',\
                                                       'dotrecordable' : 'DotRecordable', 'video':'Video','prev':'Preventable', 'status' : 'ClaimStatus', 'claimadj':'ClaimAdj', 'notes':'Notes', \
                                                      'vms_accident_no':'VmsAccidentNo'})

# %%
acc2024renamed_df['Year']=2024

# %%
acc2024renamed_df.columns
# Out:
# Index(['ClaimNo', 'InsClaimNo', 'DriverName', 'EmployeeID', 'Department',
#        'UnitNo', 'AccidentDate', 'Description', 'Preventable', 'Injury',
#        'LossOfBonus', 'coaching', 'FinalJerrysEstimate', 'Estimate',
#        'OpRepair', 'Total', 'Time', 'Address', 'CityState', 'Weather',
#        'lighting', 'RoadSurface', 'RoadType', 'DriverAction', 'PoliceReport',
#        'DotRecordable', 'Video', 'Preventable', 'ClaimStatus', 'ClaimAdj',
#        'Notes', 'VmsAccidentNo', 'Year'],
#       dtype='object')

# %%
acc2024renamed_df.head()
# Out:
#           ClaimNo      InsClaimNo      DriverName      EmployeeID Department  \
# 0      010124-311  Not Registered  Douglas Bumpus               5    Charter
# 1      010524-319  Not Registered  Devon Whitmore             0-1    Charter
# 2      011124-312  Not Registered  Troy Fontechia             1-2    Charter
# 3  Not Registered  Not Registered  DERRICK  Lowe   Not Registered        RTA
# 4      012524-336  Not Registered     Estus Owens               5    Charter
#
#   UnitNo             AccidentDate  \
# 0    311  2024-01-01 00:00:00.000
# 1    319  2024-01-05 00:00:00.000
# 2    312  2024-01-11 00:00:00.000
# 3    722  2024-01-18 00:00:00.000
# 4    336  2024-01-25 00:00:00.000
#
#                                          Description Preventable  \
# 0       Turning in parking lot of Buccees hit a car.         yes
# 1  Backing bus into slot,fatigue driving back got...         yes
# 2  Car nearly crashed pick up truck while merging...          no
# ...

# %%
accidents2025_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   claimno                  57 non-null     object
#  1   insclaimno               57 non-null     object
#  2   drivername               57 non-null     object
#  3   employeeid               57 non-null     object
#  4   dept                     57 non-null     object
#  5   unitno                   57 non-null     int64
#  6   accidentdate             57 non-null     object
#  7   description              57 non-null     object
#  8   preventable?             57 non-null     object
#  9   injury                   57 non-null     object
#  10  loss_of_bonus_           57 non-null     object
#  11  coaching                 57 non-null     object
#  12  final___jerrys_estimate  57 non-null     object
#  13  est                      57 non-null     object
# ...

# %%
accidents2025_df.columns
# Out:
# Index(['claimno', 'insclaimno', 'drivername', 'employeeid', 'dept', 'unitno',
#        'accidentdate', 'description', 'preventable?', 'injury',
#        'loss_of_bonus_', 'coaching', 'final___jerrys_estimate', 'est',
#        'oprepair', 'total', 'time', 'address', 'citystate', 'weather',
#        'lighting', 'roadsurface', 'roadtype', 'driveraction', 'policereport',
#        'dotrecordable', 'video', 'prev', 'status', 'claimadj', 'notes',
#        'vms_accident_no'],
#       dtype='object')

# %%
acc2025renamed_df = accidents2025_df.rename(columns = {'claimno':'ClaimNo', 'insclaimno':'InsClaimNo', 'drivername':'DriverName','employeeid':'EmployeeID', \
                                                       'dept' : 'Department', 'unitno' : 'UnitNo', 'accidentdate':'AccidentDate', 'description':'Description','preventable?':'Preventable', \
                                                      'injury':'Injury','loss_of_bonus_':'LossOfBonus', 'final___jerrys_estimate':'FinalJerrysEstimate','est':'Estimate','oprepair':'OpRepair', \
                                                      'total':'Total','time':'Time', 'address':'Address', 'citystate':'CityState', 'weather':'Weather',\
                                                       'lightning':'Lightning', 'roadsurface':'RoadSurface', 'roadtype':'RoadType', 'driveraction':'DriverAction', 'policereport':'PoliceReport',\
                                                       'dotrecordable' : 'DotRecordable', 'video':'Video','prev':'Preventable', 'status' : 'ClaimStatus', 'claimadj':'ClaimAdj', 'notes':'Notes', \
                                                      'vms_accident_no':'VmsAccidentNo'})

# %%
acc2025renamed_df['Year']=2025

# %%
acc2025renamed_df.columns
# Out:
# Index(['ClaimNo', 'InsClaimNo', 'DriverName', 'EmployeeID', 'Department',
#        'UnitNo', 'AccidentDate', 'Description', 'Preventable', 'Injury',
#        'LossOfBonus', 'coaching', 'FinalJerrysEstimate', 'Estimate',
#        'OpRepair', 'Total', 'Time', 'Address', 'CityState', 'Weather',
#        'lighting', 'RoadSurface', 'RoadType', 'DriverAction', 'PoliceReport',
#        'DotRecordable', 'Video', 'Preventable', 'ClaimStatus', 'ClaimAdj',
#        'Notes', 'VmsAccidentNo', 'Year'],
#       dtype='object')

# %%
acc2025renamed_df.head()
# Out:
#           ClaimNo      InsClaimNo         DriverName      EmployeeID  \
# 0  Not Registered  Not Registered    Tashelia Murphy  Not Registered
# 1      011825-331  Not Registered      Alesha Harney  Not Registered
# 2      012325-715          773848  Kimberly  Perkins  Not Registered
# 3      012525-249  Not Registered          Dale Jaco  Not Registered
# 4      012925-338  Not Registered       Lonnie McGee  Not Registered
#
#    Department  UnitNo             AccidentDate  \
# 0  School Bus     593  2025-01-08 00:00:00.000
# 1     Charter     331  2025-01-18 00:00:00.000
# 2         RTA     715  2025-01-23 00:00:00.000
# 3     Charter     249  2025-01-25 00:00:00.000
# 4     Charter     338  2025-01-29 00:00:00.000
#
#                                          Description Preventable  \
# 0  I was stopped at the red light in a bit of tra...          no
# 1  Cut to close to concrete barrier getting turne...         yes
# ...

# %%
accidents2025prevent_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   claimno                  35 non-null     object
#  1   insclaimno               35 non-null     object
#  2   drivername               35 non-null     object
#  3   employeeid               35 non-null     object
#  4   dept                     35 non-null     object
#  5   unitno                   35 non-null     int64
#  6   accidentdate             35 non-null     object
#  7   description              35 non-null     object
#  8   preventable?             35 non-null     object
#  9   injury                   35 non-null     object
#  10  loss_of_bonus_           35 non-null     object
#  11  coaching                 35 non-null     object
#  12  final___jerrys_estimate  35 non-null     object
#  13  est                      35 non-null     object
# ...

# %%
accidents2025_df.columns
# Out:
# Index(['claimno', 'insclaimno', 'drivername', 'employeeid', 'dept', 'unitno',
#        'accidentdate', 'description', 'preventable?', 'injury',
#        'loss_of_bonus_', 'coaching', 'final___jerrys_estimate', 'est',
#        'oprepair', 'total', 'time', 'address', 'citystate', 'weather',
#        'lighting', 'roadsurface', 'roadtype', 'driveraction', 'policereport',
#        'dotrecordable', 'video', 'prev', 'status', 'claimadj', 'notes',
#        'vms_accident_no'],
#       dtype='object')

# %%
acc2025prevrenamed_df = accidents2025_df.rename(columns = {'claimno':'ClaimNo', 'insclaimno':'InsClaimNo', 'drivername':'DriverName','employeeid':'EmployeeID', \
                                                       'dept' : 'Department', 'unitno' : 'UnitNo', 'accidentdate':'AccidentDate', 'description':'Description','preventable?':'Preventable', \
                                                      'injury':'Injury', 'loss_of_bonus_':'LossOfBonus', 'coaching':'Coaching', 'final___jerrys_estimate':'FinalJerrysEstimate','est':'Estimate','oprepair':'OpRepair', \
                                                      'total':'Total','time':'Time', 'address':'Address', 'citystate':'CityState', 'weather':'Weather',\
                                                       'lightning':'Lightning', 'roadsurface':'RoadSurface', 'roadtype':'RoadType', 'driveraction':'DriverAction', 'policereport':'PoliceReport',\
                                                       'dotrecordable' : 'DotRecordable', 'video':'Video','prev':'Preventable', 'status' : 'ClaimStatus', 'claimadj':'ClaimAdj', 'notes':'Notes', \
                                                      'vms_accident_no':'VmsAccidentNo'})

# %%
acc2025prevrenamed_df['Year']=2025

# %%
acc2025prevrenamed_df.columns
# Out:
# Index(['ClaimNo', 'InsClaimNo', 'DriverName', 'EmployeeID', 'Department',
#        'UnitNo', 'AccidentDate', 'Description', 'Preventable', 'Injury',
#        'LossOfBonus', 'Coaching', 'FinalJerrysEstimate', 'Estimate',
#        'OpRepair', 'Total', 'Time', 'Address', 'CityState', 'Weather',
#        'lighting', 'RoadSurface', 'RoadType', 'DriverAction', 'PoliceReport',
#        'DotRecordable', 'Video', 'Preventable', 'ClaimStatus', 'ClaimAdj',
#        'Notes', 'VmsAccidentNo', 'Year'],
#       dtype='object')

# %%
acc2025prevrenamed_df.head()
# Out:
#           ClaimNo      InsClaimNo         DriverName      EmployeeID  \
# 0  Not Registered  Not Registered    Tashelia Murphy  Not Registered
# 1      011825-331  Not Registered      Alesha Harney  Not Registered
# 2      012325-715          773848  Kimberly  Perkins  Not Registered
# 3      012525-249  Not Registered          Dale Jaco  Not Registered
# 4      012925-338  Not Registered       Lonnie McGee  Not Registered
#
#    Department  UnitNo             AccidentDate  \
# 0  School Bus     593  2025-01-08 00:00:00.000
# 1     Charter     331  2025-01-18 00:00:00.000
# 2         RTA     715  2025-01-23 00:00:00.000
# 3     Charter     249  2025-01-25 00:00:00.000
# 4     Charter     338  2025-01-29 00:00:00.000
#
#                                          Description Preventable  \
# 0  I was stopped at the red light in a bit of tra...          no
# 1  Cut to close to concrete barrier getting turne...         yes
# ...

# %%
acc2025prevrenamed_df.columns
# Out:
# Index(['ClaimNo', 'InsClaimNo', 'DriverName', 'EmployeeID', 'Department',
#        'UnitNo', 'AccidentDate', 'Description', 'Preventable', 'Injury',
#        'LossOfBonus', 'Coaching', 'FinalJerrysEstimate', 'Estimate',
#        'OpRepair', 'Total', 'Time', 'Address', 'CityState', 'Weather',
#        'lighting', 'RoadSurface', 'RoadType', 'DriverAction', 'PoliceReport',
#        'DotRecordable', 'Video', 'Preventable', 'ClaimStatus', 'ClaimAdj',
#        'Notes', 'VmsAccidentNo', 'Year'],
#       dtype='object')

# %%
graylinefleet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325 entries, 0 to 324
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   vms-id                325 non-null    object
#  1   fleetno               325 non-null    object
#  2   vin                   325 non-null    object
#  3   modelyear             325 non-null    object
#  4   fleet_age             325 non-null    object
#  5   fleet_age_sort        325 non-null    int64
#  6   current_fleet_status  325 non-null    object
#  7   license_plate         325 non-null    object
#  8   vms_type              325 non-null    object
#  9   dept                  325 non-null    object
#  10  make                  325 non-null    object
#  11  model                 325 non-null    object
#  12  pax                   325 non-null    object
# dtypes: int64(1), object(12)
# memory usage: 33.1+ KB
