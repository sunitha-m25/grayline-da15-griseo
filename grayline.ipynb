# %%
#pip install pandas openpyxl
import sys
# !{sys.executable} -m pip install openpyxl
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
import os
print(os.listdir('data'))

# %%
accidents2018_df = pd.read_excel('data/2018 Accident Incident Report.xlsx', sheet_name = 'Sheet1',skiprows=[0,1,116,117,118,119], engine='openpyxl')
consolidatedaccidents2019_df = pd.read_excel('data/finaldaccidents2019.xlsx', engine='openpyxl')
accidents2020_df = pd.read_excel('data/2020 Accident Report.xlsx', sheet_name = 'Master', engine='openpyxl')
accidents2021_df = pd.read_excel('data/2021 Accident Report.xlsx', sheet_name = 'Master', engine='openpyxl')
accidents2024_df = pd.read_csv('data/accidents_2024.csv')
accidents2025_df = pd.read_csv('data/accidents_2025.csv')
accidents2025prevent_df = pd.read_csv('data/accidents_2025_preventable_addition.csv')
graylinefleet_df = pd.read_csv('data/grayline_fleet_vehicles.csv')

# %%
accidents2018_df.info()

# %%
accidents2018_df.columns

# %%
acc2018renamed_df = accidents2018_df.rename(columns = {'Claim #':'ClaimNo', 'Employee Name':'DriverName', 'Dept.':'Department', 'Date Occurred ':'AccidentDate', \
                                                      'Incident / Accident':'IncidentAccident','Description':'Description','Unit No.':'UnitNo', 'GL Driver':'GLDriverFault', \
                                                      'NON GL Driver ':'NonGLDriverFault', 'GL Employee':'GLEmployeeInjury', 'NON GL Employee':'NonGLEmployeeInjury', \
                                                      "Jerry's $ GL Bus Repair ":'JerrysGLBusRepair', \
                                                      'Ins. Notified':'InsNotified', 'In-House, Protective, or Other Driver/Insuance ':'ClaimType', 'Quote':'Quote', \
                                                     'Actual':'Actual', 'Cost for other vehicle repair':'CostForOtherVehicleRepair', 'Police Report':'PoliceReport', \
                                                      'Drive Cam?':'DriveCam', 'Safety Committee Ruling':'SafetyCommRuling','DOT Recordable?':'DOT Recordable', \
                                                      'Status':'ClaimStatus'})

# %%
acc2018renamed_df['Year'] = 2018

# %%
acc2018renamed_df.head()

# %%
acc2018renamed_df.columns

# %%
consolidatedaccidents2019_df.info()

# %%
consolidatedaccidents2019_df.columns

# %%
consolidatedaccidents2019_df.head()

# %%
accidents2020_df.info()

# %%
accidents2020_df.columns

# %%
acc2020renamed_df = accidents2020_df.rename(columns = {'CLAIM NUMBER' : 'ClaimNo', 'CLAIM NUMBER2' : 'InsClaimNo', 'DRIVER NAME' : 'DriverName',\
                                                      'EMPLOYEE ID' : 'EmployeeId',  'DEPARTMENT' : 'Department', 'ACC DATE': 'AccidentDate', \
                                                      'DESCRIPTION' : 'Description', 'DRIVER INJURED' : 'DriverInjured', 'OP INJURED' : 'OpInjured', \
                                                      'CLAIM TYPE' : 'ClaimType', 'GL BUS ESTIMATE' : 'GLBusEstimate', 'GL BUS REPAIR' : 'GLBusRepair', \
                                                      'OP REPAIR COST' : 'OpRepairCost', 'INS FEE' : 'InsFee', 'OP INS PAID TO GL' : 'OpInsPaid', \
                                                      'INSURANCE DEDUCTIBLE' : 'InsDeductable', 'TOTAL' : 'Total', 'TIME' : 'Time', 'LOCATION' : 'Location', \
                                                      'WEATHER' : 'Weather', 'LIGHTING' : 'Lighting', 'ROAD SURFACE' : 'RoadSurface', 'ROAD TYPE' : 'RoadType', \
                                                      'DRIVER ACTION' : 'DriverAction','DRIVER EXPERIENCE' : 'DriverExperience', 'RADIUS' : 'Radius', \
                                                      'POLICE REPORT' : 'PoliceReport', 'DOT RECORDABLE' : 'DOT Recordable', 'VIDEO' : 'Video',\
                                                      'PREVENTABLE?' : 'Preventable', 'STATUS' : 'ClaimStatus', 'UNIT NO' : 'UnitNo', \
                                                      'GL FINAL COST':'GLFinalCost'})

# %%
acc2020renamed_df['Year'] = 2020

# %%
acc2020renamed_df.head()

# %%
acc2020renamed_df.columns

# %%
accidents2021_df.info()

# %%
accidents2021_df.columns

# %%
acc2021renamed_df = accidents2021_df.rename(columns = {'ClaimNo' : 'ClaimNo', 'InsClaimNo' : 'InsClaimNo', 'DRIVERNAME' : 'DriverName','EmployeeID' : 'EmployeeId', \
                                                      'DEPT' : 'Department', 'UnitNo' : 'UnitNo', 'DESCRIPTION' : 'Description', \
                                                      'OPFAULT' : 'OpFault', 'INJURY' : 'Injury', 'GL Estimate':'GLBusEstimate', 'OPRepair':'OpRepairCost',\
                                                      'TIME':'Time', 'LOCATION':'Location', 'WEATHER':'Weather', \
                                                      'LIGHTING':'Lighting', 'RoadSurface':'RoadSurface', 'RoadType':'RoadType', 'DriverAction':'DriverAction', \
                                                      'DOTRecordable' : 'DOT Recordable', 'VIDEO': 'Video', 'PREV':'Preventable', \
                                                      'Date Occured': 'AccidentDate', 'STATUS' : 'ClaimStatus', 'NOTES':'Notes', 'VMS Accident No':'VMSAccidentNo'})

# %%
acc2021renamed_df['Year'] = 2021

# %%
acc2021renamed_df.head(5)

# %%
acc2021renamed_df.columns

# %%
accidents2024_df.info()

# %%
accidents2024_df['Year'] = 2024

# %%
accidents2024_df.columns

# %%
accidents2024_df = accidents2024_df.rename(columns= {'address':'Location'})

# %%
# To see all the columns
pd.set_option('display.max_columns', None)

# %%
accidents2024_df.head()

# %%
accidents2025_df.info()

# %%
accidents2025_df['Year'] = 2025

# %%
accidents2025_df.columns

# %%
accidents2025_df = accidents2025_df.rename(columns= {'address':'Location'})

# %%
accidents2025_df.head()

# %%
accidents2025prevent_df.info()

# %%
accidents2025prevent_df['Year'] = 2025

# %%
accidents2025prevent_df.columns

# %%
accidents2025prevent_df.head()

# %%
graylinefleet_df.columns

# %%
graylinefleet_df.columns

# %%
graylinefleetrenamed_df = graylinefleet_df.rename(columns = {'vms-id':'VMSId', 'fleetno':'FleetNo','vin':'VIN', 'modelyear':'ModelYear', 'fleet_age':'FleetAge', \
                                                                    'fleet_age_sort':'FleetAgeSort', 'current_fleet_status':'CurrenFleetStatus', \
                                                                    'license_plate':'LicensePlate', 'vms_type':'VMSType', 'dept':'Department', \
                                                                    'make':'Make', 'model':'Model', 'pax':'Pax'})

# %%
graylinefleetrenamed_df.head()

# %%
graylinefleetrenamed_df.info()

# %% [markdown]
# ## Merging all 4 xlxs files into one file

# %%
merged_df = pd.concat([acc2018renamed_df, consolidatedaccidents2019_df,acc2020renamed_df,acc2021renamed_df], ignore_index=True, axis=0)

# %%
merged_df.columns

# %%
merged_df.head()

# %%
merged_df.columns

# %%
merged_df.info()

# %% [markdown]
# ## Merging csv files into one file

# %%
#combined_df = pd.concat([df1, df2, df3], ignore_index=True, sort=False)
#merged1_df = pd.concat([acc2024renamed_df, acc2025renamed_df],ignore_index=True, sort=False)
merged1_df = pd.concat([accidents2024_df, accidents2025_df], ignore_index=True, axis=0)

# %%
merged1_df.head()

# %%
merged1_df.columns

# %%
finalcsv_df = merged1_df.rename(columns = {'claimno':'ClaimNo','insclaimno':'InsClaimNo','drivername':'DriverName', 'employeeid':'EmployeeId', \
                                                       'dept':'Department', 'unitno':'UnitNo', 'accidentdate':'AccidentDate', 'description':'Description', \
                                                       'preventable?':'Preventable', 'injury':'Injury','loss_of_bonus_':'LossOfBonus','coaching':'Coaching', \
                                                       'final___jerrys_estimate':'FinalJerrysEstimate', \
                                                       'est':'Estimate', 'oprepair':'OpRepairCost', 'total':'Total', 'time':'Time', 'citystate':'CityState', 'weather':'Weather', \
                                                       'lighting':'Lighting', 'roadsurface':'RoadSurface', 'roadtype':'RoadType', 'driveraction':'DriverAction','policereport':'PoliceReport', \
                                                      'dotrecordable' : 'DOT Recordable','video':'Video', 'prev':'Prev', 'status' : 'ClaimStatus', \
                                                      'claimadj':'ClaimAdj', 'notes':'Notes','vms_accident_no':'VMSAccidentNo'})

# %%
finalcsv_df

# %%
finalcsv_df.info()

# %% [markdown]
# ## Merging both final Excel and final csv files

# %%
final_df = pd.concat([merged_df, finalcsv_df], ignore_index=True, axis=0)

# %%
final_df.columns

# %%
final_df

# %%
final_df.info()

# %% [markdown]
# ## Cleaning the data

# %%
# Claim Number retrieval from Accident date and unit no
# Convert AccidentDate to datetime
final_df['AccidentDate'] = pd.to_datetime(final_df['AccidentDate'], errors='coerce')

# Format as MMDDYY (with leading zeros) and keep as string
final_df['AccidentDateFormatted'] = (
    final_df['AccidentDate'].dt.strftime('%m%d%y').where(final_df['AccidentDate'].notna())
)

# Combine into NewClaimNo
final_df['NewClaimNo'] = (
    final_df['AccidentDateFormatted'] + '-' + final_df['UnitNo'].astype('string')
)

# View the result
print(final_df[['AccidentDate', 'UnitNo', 'AccidentDateFormatted', 'NewClaimNo']])

# %%
# Clean the DriverName column
final_df['DriverName'] = (
    final_df['DriverName']
    .str.replace(',', '', regex=False)         # Remove commas
    .str.strip()                               # Remove leading/trailing whitespace
    .str.replace(r'\s+', ' ', regex=True)      # Collapse multiple spaces into one
)

# Converting date time to date only
final_df['AccidentDate'] = pd.to_datetime(final_df['AccidentDate'], errors='coerce')

#Fixing the multiple column values to 'Y' and 'N' for 'DOT Recordable'
final_df['DOT Recordable'] = final_df['DOT Recordable'].replace({'Non-DOT':'N', 
                                                                 'DOT':'Y', 
                                                                 'FALSE':'N',
                                                                 'TRUE':'Y',
                                                                 False:'N', 
                                                                 True: 'Y', 
                                                                 'non-DOT':'N', 
                                                                 'NON-DOT':'N', 
                                                                 'NON DOT': 'N', 
                                                                 '?':'Not Registered',
                                                                 'NON -DOT':'N'})

final_df['DOT Recordable'] = final_df['DOT Recordable'].fillna('NA')



#Fixing the multiple column values of 'IncidentAccident' column
final_df['IncidentAccident'] = final_df['IncidentAccident'].replace({'?':'Not Registered',
                                                                     'Accident ':'Accident',
                                                                     'Accidednt ':'Accident',
                                                                     'Accident?':'Accident',
                                                                     'Accidnet':'Accident',
                                                                     'accident':'Accident',
                                                                     'accident ':'Accident',
                                                                     'INCIDENT':'Incident',
                                                                     'Incident ':'Incident',
                                                                     'ACCIDENT':'Accident',
                                                                     'Accicdent ':'Accident',
                                                                     'Accidednt':'Accident',
                                                                     'Incident / Accident':'Incident / Accident',
                                                                     'Mystery ':'Mystery'})
final_df['IncidentAccident'] = final_df['IncidentAccident'].fillna('NA')

#Fixing the multiple column values of 'PoliceReport' column
final_df['PoliceReport'] = final_df['PoliceReport'].replace({'No':'N',
                                                             'Yes':'Y',
                                                             'FALSE':'N',
                                                             'TRUE':'Y',
                                                             False:'N',
                                                             True:'Y',
                                                             'Na':'Not Registered'})

##Fixing the multiple column values of 'DriverInjured' column
final_df['DriverInjured'] = final_df['DriverInjured'].replace({'FALSE':'N',
                                                               'TRUE' : 'Y',
                                                                False:'N',
                                                                True:'Y'
                                                               })

##Fixing the multiple column values of 'OpInjury' column
final_df['OpInjured'] = final_df['OpInjured'].replace({'FALSE':'N',
                                                       'TRUE' : 'Y',
                                                        False:'N',
                                                        True:'Y'
                                                       })

##Fixing the multiple column values of 'Injury' column
final_df['Injury'] = final_df['Injury'].replace({'No':'N',
                                                 'NO':'N',
                                                 'No ':'N',
                                                 'no':'N',
                                                 'Yes':'Y',
                                                 'FALSE':'N',
                                                 'TRUE':'Y',
                                                  False:'N'
                                                })





final_df['Weather'] = final_df['Weather'].replace({'Cler':'Clear and Sunny',
                                                   'clear':'Clear and Sunny',
                                                   'CLear':'Clear and Sunny',
                                                   'Clear':'Clear and Sunny',
                                                   'Windy':'Clear and Sunny',
                                                   'cloudy':'Cloudy',
                                                   'Dreary':'Cloudy',
                                                   'Overcast':'Cloudy',
                                                   'Dry': 'Clear and Sunny',
                                                   'dry':'Clear and Sunny',
                                                   'Mostly sunny':'Clear and Sunny',
                                                   'It had just started to rain after the accident ':'Cloudy',
                                                   'Although weather was clear but it happen either over night or next day ':'Clear and Sunny',
                                                   'Heavy rain and fog':'Rain',
                                                   'rain':'Rain',
                                                   'Sprinkle ':'Rain',  
                                                   'Icy roads':'Snow and Icy',
                                                   'Sleet': 'Snow and Icy',
                                                   'Snow': 'Snow and Icy',
                                                   '?': 'Not Registered',
                                                   'Notclear':'Not Registered',
                                                   'N':'Not Registered'
                                               })



final_df['Lighting'] = final_df['Lighting'].replace({'dark':'Night',
                                                     'Dark':'Night',
                                                 'Dark no street lights':'Night',
                                                 'Dark, no street lights on':'Night',
                                                 'Dark, No Street Light':'Night',
                                                 'Dark, Street Lights On':'Night',
                                                 'Dawn':'Morning',
                                                 'dawn':'Morning',
                                                 'morning':'Morning',
                                                 'dusk':'Evening',
                                                 'Dusk':'Evening',
                                                 'evening':'Evening',
                                                 'Daylight': 'Daytime',
                                                 'daylight':'Daytime',
                                                 'light':'Daytime',
                                                 'cloudy':'Daytime',
                                                 'Cloudy':'Daytime',
                                                 'night':'Night',
                                                  })


##Fixing the multiple column values of 'SafetyCommRuling' column

final_df['Prevent'] = final_df['SafetyCommRuling'].combine_first(final_df['Preventable'])
final_df['Prevent'] = final_df['Prevent'].replace({'Non-Preventable':'N',
                                                   'Preventable':'Y',
                                                   'o-Prevetable':'N',
                                                   'Non-Preventable ':'N',
                                                   'no':'N',
                                                   'no ':'N',
                                                   'yes':'Y',
                                                   'Yes':'Y',
                                                   'True':'Y',
                                                   'No':'N',
                                                    False:'N',
                                                    True:'Y'
                                                  })


final_df = final_df.drop(columns=['SafetyCommRuling', 'Preventable'])


final_df['RoadSurface'] = final_df['RoadSurface'].replace({'Dry':'Dry',
                                                           'DRY':'Dry',
                                                   'Wet':'Wet',
                                                   'dry':'Dry',
                                                   'muddy':'Muddy',
                                                   'Muddy':'Muddy',
                                                   'gravel':'Gravel',
                                                   'Gravel/Dirt':'Gravel',
                                                   'Gravel':'Gravel',
                                                   "It didn't start to rain until after the accident ":'Dry',
                                                   'Icy':'Icy',
                                                   'Snowy':'Snow',
                                                   'paved':'Paved',
                                                   'Parking Lot':'Parking Lot',
                                                   'N':'NA'
                                                  })

# %%
final_df['CityState'] = final_df['CityState'].replace({'Bolling Green, KY':'Bowling Green,KY',
                                                       'Athens GA':'Athens,GA',
                                                       'Nashville, TN':'Nashville,TN',
                                                       'Nashville Tennessee':'Nashville,TN',
                                                       'Nashville, TN ':'Nashville,TN',
                                                       'Nashville TN ':'Nashville,TN',
                                                       'Nashville TN ':'Nashville,TN',
                                                       'Nashville Tn ':'Nashville,TN',
                                                       'Nashville, Tn':'Nashville,TN',
                                                       'Nashville':'Nashville,TN',
                                                       'Nashville Tn':'Nashville,TN',
                                                       'Nashville. Tn':'Nashville,TN',
                                                       'Nashville TN':'Nashville,TN',
                                                       'Lebanon tn':'Lebanon,tn',
                                                       'Atlanta Georgia ':'Atlanta,GA',
                                                       'Atlanta GA':'Atlanta,GA',
                                                       'Carbondale, IL':'Carbondale,IL',
                                                       'Nashville  Tennessee ':'Nashville,TN',
                                                       'Elizabeth town kentucky':'Elizabeth Town,KY',
                                                       'Boston Massachusetts':'Boston,MA',
                                                       'Chattanooga, TN':'Chattanooga,TN',
                                                       'Nashville tn bna airport':'Nashville,TN',
                                                       'Nashville ':'Nashville,TN',
                                                       'Nashville,TN ':'Nashville,TN',
                                                       'Nashville, Tn.':'Nashville,TN',
                                                       'Nashville Tennessee ':'Nashville,TN',
                                                       'Nashville, Tennessee ':'Nashville,TN',
                                                       'Nashville tn ':'Nashville,TN',
                                                       'Nashville,Tn':'Nashville,TN',
                                                       '2200 Elm Hill Pike':'Nashville,TN',
                                                       'Nashville BNA DROP OFF departures':'Nashville,TN',
                                                       'Nashville , Tn':'Nashville,TN',
                                                       'Near Pelham TN':'Pelham,TN',
                                                       'Chicago Ill':'Chicago,IL',
                                                       'Between  Louisville and Cincinnati ':'Louisville,KY',
                                                       'Bowling Green Kentucky ':'Bowling Green,KY',
                                                       'Dahlonea GA1':'Dahlonea,GA',
                                                       'Revere, Massachusetts ':'Revere,MA ',
                                                       'Boston, MA':'Boston,MA',
                                                       'Alexandria Va':'Alexandria,VA',
                                                       'Washington DC.':'Washington DC,DC',
                                                       'Washington DC':'Washington DC,DC',
                                                       'Washington D.C.':'Washington DC,DC',
                                                       'Tupelo Ms.':'Tupelo,MS',
                                                       'Belvedere Tennessee ':'Belvedere,TN',
                                                       'NashvilleTn ':'Nashville,TN',
                                                       'Nashville ,TN':'Nashville,TN',
                                                       'Madison Tn ':'Madison,TN',
                                                       'Mackinaw City, Michigan. ':'Mackinaw City,MI',
                                                       'Hendersonville Tennessee':'Hendersonville,TN',
                                                       'Chester NY':'Chester,NY',
                                                       'Shelbyville, TN':'Shelbyville,TN',
                                                       'West Frankfurt,  IL ':'West Frankfurt,IL',
                                                       'Missouri entering Illinois (approximately)':'St.Louis,MO',
                                                       'Outter Limits Ashville NC Mile Marker 43 I-40W':'Ashville,NC',
                                                       'Nashville TN Lipscomb university ':'Nashville,TN',
                                                       'Whites Creek, TN':'Whites Creek,TN',
                                                       'Nashville  TN ':'Nashville,TN',
                                                       'Nasshville Tn':'Nashville,TN',
                                                       'Ft. Campbell, KY.':'Ft.Campbell,KY',
                                                       'Birmingham AL':'Birmingham,AL',
                                                       'Antioch, TN':'Antioch,TN',
                                                       'Nashville,  TN':'Nashville,TN',
                                                       'Nashville tN':'Nashville,TN',
                                                       'Nashville tn':'Nashville,TN',
                                                       'Nashville,Tennessee ':'Nashville,TN',
                                                       'Clinton, MS':'Clinton,MS',
                                                       'Nashville, Tennessee':'Nashville,TN',
                                                       'Lebanon Lot Nashville, TN':'Lebanon,TN',
                                                       'Nashville, Tn ':'Nashville,TN',
                                                       'Atlanta ga':'Atlanta,GA',
                                                       'Antioch TN':'Antioch,TN',
                                                       'Lynchburg TN.':'Lynchburg,TN',
                                                       'Warenton Virginia':'Warenton,VA',
                                                       'Near Joelton, TN':'Joelton,TN',
                                                       'Branson Mo.':'Branson,MO',
                                                       'Courtyard Green Hills 3800 Bedford Ave':'Green Hills,TN',
                                                       'Franklin, TN':'Franklin,TN',
                                                       'Boston mass...mass ave by Harvard ':'Boston,MA',
                                                       'Boston, Massachusetts':'Boston,MA',
                                                       'Nashville  Tn':'Nashville,TN',
                                                       'Cornelia':'Cornelia,GA',
                                                       'Jacksonville Alabama ':'Jacksonville,AL',
                                                       'Jacksonville, Alabama ':'Jacksonville,AL',
                                                       'Hopkinsville Ky':'Hopkinsville,Ky',
                                                       'Nashville Tn.':'Nashville,TN',
                                                       'Antioch , Tn':'Antioch,TN',
                                                       'Gallatin, Tennessee':'Gallatin,TN',
                                                       'Murfreesboro TN':'Murfreesboro,TN',
                                                       'Murphy Athletic Center MTSU':'Murfreesboro,TN',
                                                       'Jackson, TN ': 'Jackson,TN',
                                                       'Jackson TN':'Jackson,TN',
                                                       'Antioch tn':'Antioch,TN',
                                                       'Nashville tennessee':'Nashville,TN',
                                                       'Nashville, TN.':'Nashville,TN',
                                                       'Nashville,  Tennessee ':'Nashville,TN',
                                                       'Tn nashville':'Nashville,TN',
                                                       'Nashville  TN':'Nashville,TN',
                                                       'Nashville aTN':'Nashville,TN',
                                                       'Spring lake  NC':'Spring lake,NC',
                                                       'Antioch Tennessee ':'Antioch,TN',
                                                       'Marietta Georgia':'Marietta,GA',
                                                       'Birmingham Alabama ':'Birmingham,AL',
                                                       'Cookeville TN':'Cookeville,TN',
                                                       'I-40 east bound Sevir County  near exit 407':'Gatlinburg,TN',
                                                       'Coopertown tn':'Coopertown,TN',
                                                       'Antioch, TN ':'Antioch,TN',
                                                       'Bowling Green, KY':'Bowling Green,KY',
                                                       'Meridian MS':'Meridian,MS',
                                                       'Marion Virginia ':'Marion,VA'
       
                                                       })

# %%
final_df['City'] = final_df['CityState'].str.split(',').str[0]
final_df['City'].unique()

# %%
final_df['State'] = final_df['CityState'].str.split(',').str[1]
final_df['State'].unique()

# %%
name_typos = {
    'Bobby Richie': 'Bobby Richey',
    'William Dickersoff': 'William Dickerhoff',
    'Bill Dickerhoff': 'William Dickerhoff',
    'Bill Dickersoff': 'William Dickerhoff',
    'Austin Zumbrogrel': 'Austin Zumbrogel',
    'Bryan Espinoza': 'Bryan Espinosa',
    'Dave Armstrong': 'David Armstrong',
    'Don Thomas': 'Donald Thomas',
    'Danisha Vazquez': 'Denisha Vazquez',
    'Denisah Vazquez': 'Denisha Vazquez',
    'Douglas Bumpas': 'Douglas Bumpus',
    'Doug Bumpas': 'Douglas Bumpus',
    'Doug Bumpus': 'Douglas Bumpus',
    'Duane Alan Whitt': 'Duane Whitt',
    'Duane Allan Whitt': 'Duane Whitt',
    'Duane Alan Whit': 'Duane Whitt',
    'Duane Allan Whit': 'Duane Whitt',
    'Dwayne Alan Whitt': 'Duane Whitt',
    'Dwayne Allan Whitt': 'Duane Whitt',
    'Dwayne Whitt': 'Duane Whitt',
    'Frank Dirr': 'Francis Dirr',
    'RichardShoulders': 'Richard Shoulders',
    'Sameh shaker':'Sameh Shaker',
    'shop (R.Clark)':'Shop (R.Clark)',
    'PaulaMilligan':'Paula Milligan',
    'Trumell HaY':'Trumell Haynes',
    'Trumell Haynes?':'Trumell Haynes',
    'Mytery':'Mystery',
    'Rob Schneider':'Robert Schneider',
    'SHARON JUSTICE':'Sharon Justice',
    'jackie briggs':'Jackie Briggs',
    'Adrienne Reagan':'Adrienne Reagon',
    'Jackson Thomas': 'Thomas Jackson',
    'Jennifer Stephens': 'Jenniefer Stephens',
    'Jennifer stephens': 'Jenniefer Stephens',
    'Jennifer Stevens': 'Jenniefer Stephens',
    'Jenniefer Stevens': 'Jenniefer Stephens',
    'Jermaine McKissak': 'Jermaine McKissack',
    'Jermaine Mckissack': 'Jermaine McKissack',
    'Jermaine Mckissak': 'Jermaine McKissack',
    'John DeBose': 'John Dubose',
    'John Debose': 'John Dubose',
    'John DuBose': 'John Dubose',
    'John Tom Dubose': 'John Dubose',
    'John Tom DuBose': 'John Dubose',
    'John Tom Debose': 'John Dubose',
    'John Tom DeBose': 'John Dubose',
    'Tom Dubose': 'John Dubose',
    'Tom DuBose': 'John Dubose',
    'Tom DeBose': 'John Dubose',
    'Tome Debose': 'John Dubose',
    'Kathy Jaccobs': 'Kathy Jacobs',
    'Keela Fleming': 'Keela Fleeming',
    'Ken Dillon': 'Kenneth Dillon',
    'Lannell Mcgee': 'Lannell McGee',
    'Lannel McGee': 'Lannell McGee',
    'Lannel Mcgee': 'Lannell McGee',
     'Lugene Love Jr.': 'Lugene Love',
    'Lugene Love Jr': 'Lugene Love',
    'Lugene Love Junior': 'Lugene Love',
    'Ware Marshall': 'Marshall Ware',
    'Ware, Marshall': 'Marshall Ware',
    'Ware Marshel': 'Marshall Ware',
    'Marshall, Ware': 'Marshall Ware',
    'Marshel Ware': 'Marshall Ware',
    'Mike Beattie': 'Michael Beattie',
    'Ron King': 'Ronald King',
    'Ron King?': 'Ronald King',
    'Shawn Yorkley': 'Shawn Yokley',
    'Vicky Wooten': 'Vicky Wootton',
    'Wayne Dominquez': 'Wayne Dominguez',
    'Bill Champion': 'William Champion',
    'Bill Moncrief': 'William Moncrief',
    'Bill Schulz': 'William Schulz',
    'OWENS':'Owens'
}
final_df['DriverName'] = final_df['DriverName'].map(name_typos).fillna(final_df['DriverName'])

# %%
# Creating a unique ID for drivername
def assign_sequential_ids(DriverName):
    assigned_ids = {}
    counter = 1
    for entry in DriverName:
        if entry not in assigned_ids:
            assigned_ids[entry] = f"{counter:04d}"
            counter += 1
    return assigned_ids

DriverId = assign_sequential_ids(final_df['DriverName'])

final_df['DriverId'] = final_df['DriverName'].map(DriverId)
print(DriverId)

# %%
final_df.head()

# %%
graylinefleetrenamed_df_selected = graylinefleetrenamed_df[['FleetNo', 'Department']]
#final_df = pd.concat([df1, graylinefleetrenamed_df_selected], ignore_index=True, axis=0)
final_df1 = final_df.merge(graylinefleetrenamed_df_selected, how='left', left_on='UnitNo', right_on='FleetNo')
#result = df1.merge(df2, how='left', left_on='id1', right_on='id2')

# %%
final_df1.columns

# %%
## Convert both to string, strip spaces
final_df['UnitNo'] = final_df['UnitNo'].astype(str).str.strip().str.lower()
graylinefleetrenamed_df_selected['FleetNo'] = graylinefleetrenamed_df_selected['FleetNo'].astype(str).str.strip().str.lower()

# Merge
final_df1 = final_df.merge(
    graylinefleetrenamed_df_selected,
    how='left',
    left_on='UnitNo',
    right_on='FleetNo'
)

# %%
##Fixing the multiple column values of 'Department' column
final_df1['Depart'] = final_df1['Department_x'].combine_first(final_df1['Department_y'])
final_df1['Depart'] = final_df1['Depart'].str.strip().replace({'SB':'School Bus',
                                                            'SB ':'School Bus',
                                                           'SS':'Sightseeing',
                                                   'BC':'Black Car',
                                                   'charter':'Charter',
                                                   'C':'Charter',
                                                   'Sightseeing (Downtown/Tours)':'Sightseeing',
                                                   'SS Trolley':'Sightseeing',
                                                   'SS DoubleD':'Sightseeing',
                                                   'Tours':'Tour',
                                                   'school bus driver':'School Bus',
                                                   'Tour Guide':'Tour'})

# %%
last_df = final_df1.drop(columns=['Department_x', 'Department_y', 'FleetNo']).rename(columns={'Depart':'Department'})

# %%
last_df.columns

# %%
last_df.info()

# %%
# Changing all Nan to Not Registered as per client request.

finalcols=['ClaimNo', 'DriverName', 'AccidentDate', 'IncidentAccident',
       'DOT Recordable', 'UnitNo', 'Description', 'GLDriverFault', 'NonGLDriverFault',
       'GLEmployeeInjury', 'NonGLEmployeeInjury', 'InsNotified', 'ClaimType',
       'JerrysGLBusRepair', 'Quote', 'CostForOtherVehicleRepair', 'Actual',
       'PoliceReport', 'DriveCam', 'ClaimStatus', 'Year', 'InsClaimNo',
       'GLRepairCost', '3rdPartyCost', 'InsFee', 'Time', 'Location', 'Weather',
       'Lighting', 'RoadSurface', 'RoadType', 'ControlDevice',
       'DriverExperience', 'DriverInfo', 'EmployeeId', 
       'DriverInjured', 'OpInjured', 'GLBusEstimate', 'GLBusRepair', 
       'GLFinalCost', 'OpRepairCost', 'OpInsPaid', 'InsDeductable', 'Total', 
       'DriverAction', 'Radius', 'Video', 'OpFault', 'Injury', 'GLEstimate', 
       'Final', 'CityState', 'ClaimAdj', 'Notes', 'VMSAccidentNo', 
       'LossOfBonus', 'Coaching', 'FinalJerrysEstimate', 'Estimate', 
       'Prev', 'AccidentDateFormatted', 'NewClaimNo', 'Prevent','City', 'State', 'DriverId', 'Department']

last_df[finalcols] = last_df[finalcols].fillna('NA')
last_df[finalcols] = last_df[finalcols].replace({'NaN': 'NA'})
last_df[finalcols] = last_df[finalcols].replace({'Not Registered': 'Not Provided'})
last_df['AccidentDate'] = pd.to_datetime(last_df['AccidentDate'], errors='coerce')

# %%
# Changing all Numeric/float values to '0' as per client request.

last_df['JerrysGLBusRepair'] = last_df['JerrysGLBusRepair'].replace({'Not Provided': 0})
last_df['Quote'] = pd.to_numeric(last_df['Quote'], errors='coerce').fillna(0)
last_df['CostForOtherVehicleRepair'] = last_df['CostForOtherVehicleRepair'].replace({'NA': 0})
last_df['Actual'] = last_df['Actual'].replace({'NA': 0})
#last_df['GLRepairCost'] = last_df['GLRepairCost'].replace({'Not Registered': 0})
#last_df['3rdPartyCost'] = last_df['3rdPartyCost'].replace({'Not Registered': 0})
last_df['GLBusEstimate'] = last_df['GLBusEstimate'].replace({'NA': 0})
last_df['GLBusRepair'] = last_df['GLBusRepair'].replace({'NA': 0})
last_df['GLFinalCost'] = last_df['GLFinalCost'].replace({'NA': 0})
last_df['OpRepairCost'] = last_df['OpRepairCost'].replace({'Not Provided': 0})
last_df['OpRepairCost'] = last_df['OpRepairCost'].replace({'NA': 0})
last_df['InsFee'] = last_df['InsFee'].replace({'NA': 0})
last_df['DriverId'] = last_df['DriverId'].replace({'NA': 0})
last_df['OpInsPaid'] = last_df['OpInsPaid'].replace({'NA': 0})
last_df['OpFault'] = last_df['OpFault'].replace({'NA': 0})
last_df['GLEstimate'] = last_df['GLEstimate'].replace({'NA': 0})
last_df['Final'] = last_df['Final'].replace({'NA': 0})
last_df['InsDeductable'] = last_df['InsDeductable'].replace({'NA': 0})
last_df['Total'] = last_df['Total'].replace({'Not Provided': 0})
last_df['Total'] = last_df['Total'].replace({'NA': 0})
last_df['FinalJerrysEstimate'] = last_df['FinalJerrysEstimate'].replace({'NA': 0})
#last_df['FinalJerrysEstimate'] = last_df['FinalJerrysEstimate'].replace({' ': 0})
last_df['Estimate'] = last_df['Estimate'].replace({'Not Provided': 0})
last_df['Estimate'] = last_df['Estimate'].replace({'NA': 0})

# %%
last_df['FinalJerrysEstimate'] = last_df['FinalJerrysEstimate'].str.replace(',', '', regex=False)  # Remove commas
last_df['FinalJerrysEstimate'] = last_df['FinalJerrysEstimate'].str.extract(r'([\d\.]+)', expand=False)  # Extract first numeric part
last_df['FinalJerrysEstimate'] = pd.to_numeric(last_df['FinalJerrysEstimate'], errors='coerce')  # Convert to float
last_df['FinalJerrysEstimate'] = last_df['FinalJerrysEstimate'].replace({' ': '0'})
last_df.head()

# %%
last_df['GLDriverFault'] =last_df['GLDriverFault'].replace({'X': 'Y', 'x':'Y'})
last_df['GLDriverFault'] =last_df['GLDriverFault'].replace({'Not Registered': 'N'})
last_df['GLEmployeeInjury'] =last_df['GLEmployeeInjury'].replace({'X': 'Y', 'x':'Y'})
last_df['NonGLDriverFault'] =last_df['NonGLDriverFault'].replace({'X': 'Y'})
last_df['NonGLDriverFault'] =last_df['NonGLDriverFault'].replace({'Not Registered': 'N'})
last_df['PoliceReport'] =last_df['PoliceReport'].replace({'Not Registered': 'N'})
last_df['DriveCam'] =last_df['DriveCam'].replace({'Not Registered': 'N'})

# %%
last_df['NonGLDriverFault'] =last_df['NonGLDriverFault'].replace({'Not Registered': 'N'})

# %%
last_df['UnitNo'] = last_df['UnitNo'].apply(lambda x: x.split('/')[0] if '/' in x else x)
last_df['UnitNo'] = last_df['UnitNo'].apply(lambda x: x.split(',')[0] if ',' in x else x)
last_df['UnitNo'] = last_df['UnitNo'].apply(lambda x: x.split(' - ')[1] if ' - ' in x else x)
last_df['UnitNo'] = last_df['UnitNo'].apply(lambda x: x.split(' ')[0] if ' ' in x else x)
last_df['UnitNo'] = last_df['UnitNo'].str.replace("-", "")
last_df['UnitNo'] = last_df['UnitNo'].replace('nan', '')
last_df['UnitNo'] = last_df['UnitNo'].replace('n', '')
last_df['UnitNo'] = pd.to_numeric(last_df['UnitNo'], errors='coerce').fillna(0)

# %%
last_df['NewClaimNo'] = (
    last_df['AccidentDateFormatted'] + '-' + last_df['UnitNo'].astype('string'))
# Remove '.0' at the end of each string
last_df['NewClaimNo'] = last_df['NewClaimNo'].str.replace(r'\.0$', '', regex=True)

# %%
last_df = last_df.drop(columns=['ClaimNo', 'AccidentDateFormatted']).rename(columns={'NewClaimNo':'ClaimNo'})

# %%
last_df = last_df.drop_duplicates(keep='first')

# %%
last_df = last_df.rename(columns = {'DOT Recordable':'DOTRecordable'})

# %%
last_df['GLAndNonGLInjury'] = last_df.apply(lambda row: 'Y' if (row['GLEmployeeInjury'] == 'Y' and row['NonGLEmployeeInjury'] == 'N') or
                                   (row['GLEmployeeInjury'] == 'N' and row['NonGLEmployeeInjury'] == 'Y') or
                                  (row['GLEmployeeInjury'] == 'Y' and row['NonGLEmployeeInjury'] == 'Y')                                  
                                  else 'N', axis=1)

# %%
last_df['InjuryFinal'] = last_df.apply(lambda row: 'Y' if (row['GLAndNonGLInjury'] == 'Y' and row['Injury'] == 'N') or
                                   (row['GLAndNonGLInjury'] == 'N' and row['Injury'] == 'Y') or
                                  (row['GLAndNonGLInjury'] == 'Y' and row['Injury'] == 'Y') or
                                  (row['GLAndNonGLInjury'] == 'Y' and row['Injury'] == 'NA')     
                                  else 'N', axis=1)

# %% [raw]
# roadtype_clean = {
#     'Bus Station ':'Bus Station',
#     'Patking Lot':'Parking Lot',
#     'parking Lot': 'Parking Lot',
#     'Patking Log':'Parking Lot',
#     'Turning into church parking lot': 'Parking Lot',
#     'nan': 'Not Provided',
#     'NaN': 'Not Provided',
#     'Residential Driveway': 'Residential Street',
#     'interstate': 'Interstate',
#     'Divided ': 'Divided',
#     'divided': 'Divided',
#     'divided ': 'Divided',
#     'two lane st': '2 Lane St',
#     '21st Ave & Medical Center': 'Residential or City Street',
#     'paved ': 'Paved',
#     'paved': 'Paved',
#     'Asphalt': 'Paved',
#     'Gravel': 'Unpaved',
#     'Dirt Road': 'Unpaved',
#     'Lebanon Pike or Shop Parking Lot': 'Shop Lot',
#     'Dickerson pik shop ': 'Shop Lot',
#     'Downtown - Nashville': 'Downtown',
#     'Dickerson pike by school ': 'Highway',
#     'Was unloading': 'Other',
#     'Under stadium ': 'Other',
#     'Straight': 'Other',
#     'N': 'Other',
#     'Upgrade': 'Other',
#     'Level': 'Other',
#     'level': 'Other',
#     'Inn at Opryland': 'Other',
#     'Golf club': 'Other',
#     'Not Registered': 'Not Provided',
# }
# last_df['RoadType'] = last_df['RoadType'].map(roadtype_clean).fillna(last_df['RoadType'])

# %%
Roadtype_Clean = {'Not Registered':'NA', 'Straight':'Other',
                                                   'N':'NA', 'Level':'Other', 'level':'Other',
                                                   'Paved':'Paved', 'paved':'Paved','Gravel':'UnPaved', 'Unpaved': 'UnPaved',
                                                   'Parking Lot':'ParkingLot', 'Upgrade':'Other', 'Divided ':'Other',
                                                   'Divided':'Other', 'divided':'Other', 'Asphalt':'Paved',
                                                   'Road Side/Curb/Ditch':'Other', 'Other':'Other','Driveway':'Residential',
                                                   'Interstate':'Interstate', 'Residential Street':'Residential',
                                                   'two lane st':'Residential', 'RoadSide':'Other',
                                                   'Train Station':'TrainStation', '4 lane st':'Residential',
                                                   'Roundabout':'Other', 'Roundabout ':'Other', 'Shop Lot':'ShopLot',
                                                   'Downtown':'Downtown', 'Dirt Road':'UnPaved',
                                                   'Highway':'Interstate', 'interstate':'Interstate',
                                                   'parking Lot':'ParkingLot', 'Inn at Opryland':'Other',
                                                   'Private Rd':'Residential', 'Downtown - Nashville':'Downtown',
                                                   'Lebanon Pike or Shop Parking Lot':'ShopLot','Patking Log':'ParkingLot',
                                                   'Golf club':'Other', 'Dickerson pike by school ':'DickersonPike',
                                                   'Gas station':'GasStation', 'Was unloading':'Other','Residential or City Street':'Residential',
                                                   'Street':'Residential', 'Under stadium ':'Other', '21st Ave & Medical Center':'Downtown',
                                                   'Residential Driveway':'Residential', 'Turning into church parking lot':'ParkingLot',
                                                   'Interstate/Highway':'Interstate', 'Dickerson pik shop ':'DickersonPike',
                                                   'Loading Zone or Bus Lane':'BusStation', 'WeGo Central ':'BusStation',
                                                   'Bus Station ':'BusStation', 'Music City Central':'Downtown',
                                                   'Parking Lot (NOT Gray Line TN)':'ParkingLot', 'Bus Station':'BusStation'}
last_df['RoadType'] = last_df['RoadType'].map(Roadtype_Clean).fillna(last_df['RoadType'])

# %%
last_df['RoadType'].unique()

# %%
DriverAction_Clean = {'NA':'NA', 'Stop Sign':'Stopped', 'turning right':'RightTurn', 'N':'NA', 'stopped':'Stopped',
                      'turning left':'LeftTurn', 'Driving Forward':'Forward', 'driving forward':'Forward',
                      'Turning Right':'RightTurn', 'Traffic Signal':'Stopped', 'Backing':'Backing', 'Turning right':'RightTurn',
                      'backing':'Backing', 'Not Moving':'Stopped', 
                      'Right Turn':'RightTurn', 'Stopped not moving':'Stopped',
                       'Turning left':'LeftTurn', 'Stopped, Not Moving':'Stopped', 'Turning Left':'LeftTurn',
                       'Stopped':'Stopped', 'Left Turn':'LeftTurn','Stopped':'Stopped', 'Not Moving':'Stopped',
                       'Stopped, Not in vehicle when accident occurred':'Stopped', 'Parked':'Stopped', 'Changing Lanes':'LaneChange',
                       'Stopped':'Stopped', 'Stopped, Not Moving, Not in vehicle when accident occurred':'Stopped',
                       'Stopped, Not Moving & Not in vehicle when accident occurred':'Stopped',
                       'Not Provided':'NotProvided'}
last_df['DriverAction'] = last_df['DriverAction'].map(DriverAction_Clean ).fillna(last_df['DriverAction'])

# %%
last_df['DriverAction'].unique()

# %% [raw]
# # To see all the columns
# pd.set_option('display.max_columns', None)

# %%
last_df.head()

# %%
last_df = last_df[['Year', 'ClaimNo', 'DriverId', 'DriverName', 'UnitNo', 'Department','AccidentDate', 'IncidentAccident',  'Description', \
                   'DriverAction', 'DOTRecordable', 'GLDriverFault', 'NonGLDriverFault', 'GLEmployeeInjury', 'NonGLEmployeeInjury', \
                   'Injury', 'InjuryFinal', 'Weather', 'Lighting', 'RoadSurface', 'RoadType', 'CityState', 'City', 'State', 'InsNotified', 'Prevent', \
                   'Location', 'PoliceReport', 'ClaimStatus', 'ClaimType', 'DriverInjured', 'OpInjured', 'DriveCam', 'DriverInfo', 'DriverExperience', \
                   'EmployeeId', 'Notes', 'ControlDevice', 'Radius', 'OpFault', 'Time', 'Video', 'Coaching', 'Quote', 'JerrysGLBusRepair', \
                   'GLBusEstimate', 'GLBusRepair', 'GLFinalCost', 'CostForOtherVehicleRepair', 'OpRepairCost', 'OpInsPaid', 'InsDeductable', \
                   'Actual', 'Total', 'Estimate', 'GLEstimate', 'GLRepairCost', '3rdPartyCost', 'ClaimAdj', 'Final', 'FinalJerrysEstimate', \
                   'InsClaimNo', 'InsFee',  'VMSAccidentNo', 'LossOfBonus', 'Prev', 'GLAndNonGLInjury' ]]

# %%
last_df.to_excel('data/finaloutput.xlsx', index=False)
